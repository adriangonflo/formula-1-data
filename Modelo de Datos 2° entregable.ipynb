# %%
import requests
import json
import pandas as pd 
import warnings
import numpy as np
warnings.filterwarnings("ignore")

# %% [markdown]
# # Tabla Status

# %%
url = 'http://ergast.com/api/f1/status.json'
response = requests.get(url)
content=json.loads(response.content)

# %%
content['MRData']['StatusTable']['Status']
# Out:
# [{'statusId': '1', 'count': '7083', 'status': 'Finished'},
#  {'statusId': '2', 'count': '143', 'status': 'Disqualified'},
#  {'statusId': '3', 'count': '1044', 'status': 'Accident'},
#  {'statusId': '4', 'count': '833', 'status': 'Collision'},
#  {'statusId': '5', 'count': '2011', 'status': 'Engine'},
#  {'statusId': '6', 'count': '805', 'status': 'Gearbox'},
#  {'statusId': '7', 'count': '321', 'status': 'Transmission'},
#  {'statusId': '8', 'count': '214', 'status': 'Clutch'},
#  {'statusId': '9', 'count': '138', 'status': 'Hydraulics'},
#  {'statusId': '10', 'count': '315', 'status': 'Electrical'},
#  {'statusId': '11', 'count': '3850', 'status': '+1 Lap'},
#  {'statusId': '12', 'count': '1593', 'status': '+2 Laps'},
#  {'statusId': '13', 'count': '731', 'status': '+3 Laps'},
#  {'statusId': '14', 'count': '405', 'status': '+4 Laps'},
#  {'statusId': '15', 'count': '221', 'status': '+5 Laps'},
#  {'statusId': '16', 'count': '153', 'status': '+6 Laps'},
#  {'statusId': '17', 'count': '99', 'status': '+7 Laps'},
#  {'statusId': '18', 'count': '52', 'status': '+8 Laps'},
#  {'statusId': '19', 'count': '38', 'status': '+9 Laps'},
#  {'statusId': '20', 'count': '792', 'status': 'Spun off'},
#  {'statusId': '21', 'count': '42', 'status': 'Radiator'},
#  {'statusId': '22', 'count': '431', 'status': 'Suspension'},
#  {'statusId': '23', 'count': '250', 'status': 'Brakes'},
#  {'statusId': '24', 'count': '61', 'status': 'Differential'},
#  {'statusId': '25', 'count': '130', 'status': 'Overheating'},
#  {'statusId': '26', 'count': '28', 'status': 'Mechanical'},
#  {'statusId': '27', 'count': '55', 'status': 'Tyre'},
#  {'statusId': '28', 'count': '1', 'status': 'Driver Seat'},
#  {'statusId': '29', 'count': '41', 'status': 'Puncture'},
#  {'statusId': '30', 'count': '25', 'status': 'Driveshaft'}]

# %%
sta={'statusId':[],'count':[],'status':[]}
for year in list(range(2010,2023)):
    url='http://ergast.com/api/f1/{}/status.json'
    response = requests.get(url.format(year))
    content=json.loads(response.content)
    for item in content['MRData']['StatusTable']['Status']:
        sta['statusId'].append(item['statusId'])
        sta['count'].append(item['count'])
        sta['status'].append(item['status'])
pd.DataFrame(sta).to_csv('status.csv', index=False)

# %% [markdown]
# # Tabla results

# %%
url = 'http://ergast.com/api/f1/results.json'
response = requests.get(url)
content=json.loads(response.content)

# %%
content['MRData']['RaceTable']['Races'][0]['Results']
# Out:
# [{'number': '8',
#   'position': '1',
#   'positionText': '1',
#   'points': '25',
#   'Driver': {'driverId': 'alonso',
#    'permanentNumber': '14',
#    'code': 'ALO',
#    'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#    'givenName': 'Fernando',
#    'familyName': 'Alonso',
#    'dateOfBirth': '1981-07-29',
#    'nationality': 'Spanish'},
#   'Constructor': {'constructorId': 'ferrari',
#    'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#    'name': 'Ferrari',
#    'nationality': 'Italian'},
#   'grid': '3',
#   'laps': '49',
#   'status': 'Finished',
#   'Time': {'millis': '5960396', 'time': '1:39:20.396'},
#   'FastestLap': {'rank': '1',
#    'lap': '45',
#    'Time': {'time': '1:58.287'},
#    'AverageSpeed': {'units': 'kph', 'speed': '191.706'}}},
#  {'number': '7',
#   'position': '2',
#   'positionText': '2',
#   'points': '18',
#   'Driver': {'driverId': 'massa',
#    'permanentNumber': '19',
#    'code': 'MAS',
#    'url': 'http://en.wikipedia.org/wiki/Felipe_Massa',
#    'givenName': 'Felipe',
#    'familyName': 'Massa',
#    'dateOfBirth': '1981-04-25',
#    'nationality': 'Brazilian'},
#   'Constructor': {'constructorId': 'ferrari',
#    'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#    'name': 'Ferrari',
#    'nationality': 'Italian'},
#   'grid': '2',
#   'laps': '49',
#   'status': 'Finished',
#   'Time': {'millis': '5976495', 'time': '+16.099'},
#   'FastestLap': {'rank': '5',
#    'lap': '38',
#    'Time': {'time': '1:59.732'},
#    'AverageSpeed': {'units': 'kph', 'speed': '189.392'}}},
#  {'number': '2',
#   'position': '3',
#   'positionText': '3',
#   'points': '15',
#   'Driver': {'driverId': 'hamilton',
#    'permanentNumber': '44',
#    'code': 'HAM',
#    'url': 'http://en.wikipedia.org/wiki/Lewis_Hamilton',
#    'givenName': 'Lewis',
#    'familyName': 'Hamilton',
#    'dateOfBirth': '1985-01-07',
#    'nationality': 'British'},
#   'Constructor': {'constructorId': 'mclaren',
#    'url': 'http://en.wikipedia.org/wiki/McLaren',
#    'name': 'McLaren',
#    'nationality': 'British'},
#   'grid': '4',
#   'laps': '49',
#   'status': 'Finished',
#   'Time': {'millis': '5983578', 'time': '+23.182'},
#   'FastestLap': {'rank': '4',
#    'lap': '42',
#    'Time': {'time': '1:59.560'},
#    'AverageSpeed': {'units': 'kph', 'speed': '189.665'}}},
#  {'number': '5',
#   'position': '4',
#   'positionText': '4',
#   'points': '12',
#   'Driver': {'driverId': 'vettel',
#    'permanentNumber': '5',
#    'code': 'VET',
#    'url': 'http://en.wikipedia.org/wiki/Sebastian_Vettel',
#    'givenName': 'Sebastian',
#    'familyName': 'Vettel',
#    'dateOfBirth': '1987-07-03',
#    'nationality': 'German'},
#   'Constructor': {'constructorId': 'red_bull',
#    'url': 'http://en.wikipedia.org/wiki/Red_Bull_Racing',
#    'name': 'Red Bull',
#    'nationality': 'Austrian'},
#   'grid': '1',
#   'laps': '49',
#   'status': 'Finished',
#   'Time': {'millis': '5999195', 'time': '+38.799'},
#   'FastestLap': {'rank': '12',
#    'lap': '32',
#    'Time': {'time': '2:00.218'},
#    'AverageSpeed': {'units': 'kph', 'speed': '188.627'}}},
#  {'number': '4',
#   'position': '5',
#   'positionText': '5',
#   'points': '10',
#   'Driver': {'driverId': 'rosberg',
#    'permanentNumber': '6',
#    'code': 'ROS',
#    'url': 'http://en.wikipedia.org/wiki/Nico_Rosberg',
#    'givenName': 'Nico',
#    'familyName': 'Rosberg',
#    'dateOfBirth': '1985-06-27',
#    'nationality': 'German'},
#   'Constructor': {'constructorId': 'mercedes',
#    'url': 'http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One',
#    'name': 'Mercedes',
#    'nationality': 'German'},
#   'grid': '5',
#   'laps': '49',
#   'status': 'Finished',
#   'Time': {'millis': '6000609', 'time': '+40.213'},
#   'FastestLap': {'rank': '13',
#    'lap': '45',
#    'Time': {'time': '2:00.236'},
#    'AverageSpeed': {'units': 'kph', 'speed': '188.599'}}},
#  {'number': '3',
#   'position': '6',
#   'positionText': '6',
#   'points': '8',
#   'Driver': {'driverId': 'michael_schumacher',
#    'code': 'MSC',
#    'url': 'http://en.wikipedia.org/wiki/Michael_Schumacher',
#    'givenName': 'Michael',
#    'familyName': 'Schumacher',
#    'dateOfBirth': '1969-01-03',
#    'nationality': 'German'},
#   'Constructor': {'constructorId': 'mercedes',
#    'url': 'http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One',
#    'name': 'Mercedes',
#    'nationality': 'German'},
#   'grid': '7',
#   'laps': '49',
#   'status': 'Finished',
#   'Time': {'millis': '6004559', 'time': '+44.163'},
#   'FastestLap': {'rank': '11',
#    'lap': '45',
#    'Time': {'time': '2:00.204'},
#    'AverageSpeed': {'units': 'kph', 'speed': '188.649'}}},
#  {'number': '1',
#   'position': '7',
#   'positionText': '7',
#   'points': '6',
#   'Driver': {'driverId': 'button',
#    'permanentNumber': '22',
#    'code': 'BUT',
#    'url': 'http://en.wikipedia.org/wiki/Jenson_Button',
#    'givenName': 'Jenson',
#    'familyName': 'Button',
#    'dateOfBirth': '1980-01-19',
#    'nationality': 'British'},
#   'Constructor': {'constructorId': 'mclaren',
#    'url': 'http://en.wikipedia.org/wiki/McLaren',
#    'name': 'McLaren',
#    'nationality': 'British'},
#   'grid': '8',
#   'laps': '49',
#   'status': 'Finished',
#   'Time': {'millis': '6005676', 'time': '+45.280'},
#   'FastestLap': {'rank': '9',
#    'lap': '45',
#    'Time': {'time': '1:59.970'},
#    'AverageSpeed': {'units': 'kph', 'speed': '189.017'}}},
#  {'number': '6',
#   'position': '8',
#   'positionText': '8',
#   'points': '4',
#   'Driver': {'driverId': 'webber',
#    'code': 'WEB',
#    'url': 'http://en.wikipedia.org/wiki/Mark_Webber_(racing_driver)',
#    'givenName': 'Mark',
#    'familyName': 'Webber',
#    'dateOfBirth': '1976-08-27',
#    'nationality': 'Australian'},
#   'Constructor': {'constructorId': 'red_bull',
#    'url': 'http://en.wikipedia.org/wiki/Red_Bull_Racing',
#    'name': 'Red Bull',
#    'nationality': 'Austrian'},
#   'grid': '6',
#   'laps': '49',
#   'status': 'Finished',
#   'Time': {'millis': '6006756', 'time': '+46.360'},
#   'FastestLap': {'rank': '3',
#    'lap': '45',
#    'Time': {'time': '1:59.487'},
#    'AverageSpeed': {'units': 'kph', 'speed': '189.781'}}},
#  {'number': '15',
#   'position': '9',
#   'positionText': '9',
#   'points': '2',
#   'Driver': {'driverId': 'liuzzi',
#    'code': 'LIU',
#    'url': 'http://en.wikipedia.org/wiki/Vitantonio_Liuzzi',
#    'givenName': 'Vitantonio',
#    'familyName': 'Liuzzi',
#    'dateOfBirth': '1980-08-06',
#    'nationality': 'Italian'},
#   'Constructor': {'constructorId': 'force_india',
#    'url': 'http://en.wikipedia.org/wiki/Racing_Point_Force_India',
#    'name': 'Force India',
#    'nationality': 'Indian'},
#   'grid': '12',
#   'laps': '49',
#   'status': 'Finished',
#   'Time': {'millis': '6013404', 'time': '+53.008'},
#   'FastestLap': {'rank': '7',
#    'lap': '39',
#    'Time': {'time': '1:59.906'},
#    'AverageSpeed': {'units': 'kph', 'speed': '189.118'}}},
#  {'number': '9',
#   'position': '10',
#   'positionText': '10',
#   'points': '1',
#   'Driver': {'driverId': 'barrichello',
#    'code': 'BAR',
#    'url': 'http://en.wikipedia.org/wiki/Rubens_Barrichello',
#    'givenName': 'Rubens',
#    'familyName': 'Barrichello',
#    'dateOfBirth': '1972-05-23',
#    'nationality': 'Brazilian'},
#   'Constructor': {'constructorId': 'williams',
#    'url': 'http://en.wikipedia.org/wiki/Williams_Grand_Prix_Engineering',
#    'name': 'Williams',
#    'nationality': 'British'},
#   'grid': '11',
#   'laps': '49',
#   'status': 'Finished',
#   'Time': {'millis': '6022885', 'time': '+1:02.489'},
#   'FastestLap': {'rank': '6',
#    'lap': '47',
#    'Time': {'time': '1:59.833'},
#    'AverageSpeed': {'units': 'kph', 'speed': '189.233'}}},
#  {'number': '11',
#   'position': '11',
#   'positionText': '11',
#   'points': '0',
#   'Driver': {'driverId': 'kubica',
#    'permanentNumber': '88',
#    'code': 'KUB',
#    'url': 'http://en.wikipedia.org/wiki/Robert_Kubica',
#    'givenName': 'Robert',
#    'familyName': 'Kubica',
#    'dateOfBirth': '1984-12-07',
#    'nationality': 'Polish'},
#   'Constructor': {'constructorId': 'renault',
#    'url': 'http://en.wikipedia.org/wiki/Renault_in_Formula_One',
#    'name': 'Renault',
#    'nationality': 'French'},
#   'grid': '9',
#   'laps': '49',
#   'status': 'Finished',
#   'Time': {'millis': '6029489', 'time': '+1:09.093'},
#   'FastestLap': {'rank': '14',
#    'lap': '33',
#    'Time': {'time': '2:00.474'},
#    'AverageSpeed': {'units': 'kph', 'speed': '188.226'}}},
#  {'number': '14',
#   'position': '12',
#   'positionText': '12',
#   'points': '0',
#   'Driver': {'driverId': 'sutil',
#    'permanentNumber': '99',
#    'code': 'SUT',
#    'url': 'http://en.wikipedia.org/wiki/Adrian_Sutil',
#    'givenName': 'Adrian',
#    'familyName': 'Sutil',
#    'dateOfBirth': '1983-01-11',
#    'nationality': 'German'},
#   'Constructor': {'constructorId': 'force_india',
#    'url': 'http://en.wikipedia.org/wiki/Racing_Point_Force_India',
#    'name': 'Force India',
#    'nationality': 'Indian'},
#   'grid': '10',
#   'laps': '49',
#   'status': 'Finished',
#   'Time': {'millis': '6043354', 'time': '+1:22.958'},
#   'FastestLap': {'rank': '2',
#    'lap': '49',
#    'Time': {'time': '1:59.393'},
#    'AverageSpeed': {'units': 'kph', 'speed': '189.930'}}},
#  {'number': '17',
#   'position': '13',
#   'positionText': '13',
#   'points': '0',
#   'Driver': {'driverId': 'alguersuari',
#    'code': 'ALG',
#    'url': 'http://en.wikipedia.org/wiki/Jaime_Alguersuari',
#    'givenName': 'Jaime',
#    'familyName': 'Alguersuari',
#    'dateOfBirth': '1990-03-23',
#    'nationality': 'Spanish'},
#   'Constructor': {'constructorId': 'toro_rosso',
#    'url': 'http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso',
#    'name': 'Toro Rosso',
#    'nationality': 'Italian'},
#   'grid': '18',
#   'laps': '49',
#   'status': 'Finished',
#   'Time': {'millis': '6053052', 'time': '+1:32.656'},
#   'FastestLap': {'rank': '8',
#    'lap': '28',
#    'Time': {'time': '1:59.964'},
#    'AverageSpeed': {'units': 'kph', 'speed': '189.026'}}},
#  {'number': '10',
#   'position': '14',
#   'positionText': '14',
#   'points': '0',
#   'Driver': {'driverId': 'hulkenberg',
#    'permanentNumber': '27',
#    'code': 'HUL',
#    'url': 'http://en.wikipedia.org/wiki/Nico_H%C3%BClkenberg',
#    'givenName': 'Nico',
#    'familyName': 'Hülkenberg',
#    'dateOfBirth': '1987-08-19',
#    'nationality': 'German'},
#   'Constructor': {'constructorId': 'williams',
#    'url': 'http://en.wikipedia.org/wiki/Williams_Grand_Prix_Engineering',
#    'name': 'Williams',
#    'nationality': 'British'},
#   'grid': '13',
#   'laps': '48',
#   'status': '+1 Lap',
#   'FastestLap': {'rank': '15',
#    'lap': '34',
#    'Time': {'time': '2:01.401'},
#    'AverageSpeed': {'units': 'kph', 'speed': '186.789'}}},
#  {'number': '19',
#   'position': '15',
#   'positionText': '15',
#   'points': '0',
#   'Driver': {'driverId': 'kovalainen',
#    'code': 'KOV',
#    'url': 'http://en.wikipedia.org/wiki/Heikki_Kovalainen',
#    'givenName': 'Heikki',
#    'familyName': 'Kovalainen',
#    'dateOfBirth': '1981-10-19',
#    'nationality': 'Finnish'},
#   'Constructor': {'constructorId': 'lotus_racing',
#    'url': 'http://en.wikipedia.org/wiki/Lotus_Racing',
#    'name': 'Lotus',
#    'nationality': 'Malaysian'},
#   'grid': '21',
#   'laps': '47',
#   'status': '+2 Laps',
#   'FastestLap': {'rank': '17',
#    'lap': '47',
#    'Time': {'time': '2:02.701'},
#    'AverageSpeed': {'units': 'kph', 'speed': '184.810'}}},
#  {'number': '16',
#   'position': '16',
#   'positionText': '16',
#   'points': '0',
#   'Driver': {'driverId': 'buemi',
#    'code': 'BUE',
#    'url': 'http://en.wikipedia.org/wiki/S%C3%A9bastien_Buemi',
#    'givenName': 'Sébastien',
#    'familyName': 'Buemi',
#    'dateOfBirth': '1988-10-31',
#    'nationality': 'Swiss'},
#   'Constructor': {'constructorId': 'toro_rosso',
#    'url': 'http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso',
#    'name': 'Toro Rosso',
#    'nationality': 'Italian'},
#   'grid': '15',
#   'laps': '46',
#   'status': 'Electrical',
#   'FastestLap': {'rank': '10',
#    'lap': '41',
#    'Time': {'time': '2:00.080'},
#    'AverageSpeed': {'units': 'kph', 'speed': '188.844'}}},
#  {'number': '18',
#   'position': '17',
#   'positionText': '17',
#   'points': '0',
#   'Driver': {'driverId': 'trulli',
#    'code': 'TRU',
#    'url': 'http://en.wikipedia.org/wiki/Jarno_Trulli',
#    'givenName': 'Jarno',
#    'familyName': 'Trulli',
#    'dateOfBirth': '1974-07-13',
#    'nationality': 'Italian'},
#   'Constructor': {'constructorId': 'lotus_racing',
#    'url': 'http://en.wikipedia.org/wiki/Lotus_Racing',
#    'name': 'Lotus',
#    'nationality': 'Malaysian'},
#   'grid': '20',
#   'laps': '46',
#   'status': 'Hydraulics',
#   'FastestLap': {'rank': '18',
#    'lap': '34',
#    'Time': {'time': '2:02.930'},
#    'AverageSpeed': {'units': 'kph', 'speed': '184.465'}}},
#  {'number': '22',
#   'position': '18',
#   'positionText': 'R',
#   'points': '0',
#   'Driver': {'driverId': 'rosa',
#    'code': 'DLR',
#    'url': 'http://en.wikipedia.org/wiki/Pedro_de_la_Rosa',
#    'givenName': 'Pedro',
#    'familyName': 'de la Rosa',
#    'dateOfBirth': '1971-02-24',
#    'nationality': 'Spanish'},
#   'Constructor': {'constructorId': 'sauber',
#    'url': 'http://en.wikipedia.org/wiki/Sauber',
#    'name': 'Sauber',
#    'nationality': 'Swiss'},
#   'grid': '14',
#   'laps': '28',
#   'status': 'Hydraulics',
#   'FastestLap': {'rank': '16',
#    'lap': '27',
#    'Time': {'time': '2:01.650'},
#    'AverageSpeed': {'units': 'kph', 'speed': '186.406'}}},
#  {'number': '21',
#   'position': '19',
#   'positionText': 'R',
#   'points': '0',
#   'Driver': {'driverId': 'bruno_senna',
#    'code': 'SEN',
#    'url': 'http://en.wikipedia.org/wiki/Bruno_Senna',
#    'givenName': 'Bruno',
#    'familyName': 'Senna',
#    'dateOfBirth': '1983-10-15',
#    'nationality': 'Brazilian'},
#   'Constructor': {'constructorId': 'hrt',
#    'url': 'http://en.wikipedia.org/wiki/Hispania_Racing',
#    'name': 'HRT',
#    'nationality': 'Spanish'},
#   'grid': '23',
#   'laps': '17',
#   'status': 'Overheating',
#   'FastestLap': {'rank': '22',
#    'lap': '14',
#    'Time': {'time': '2:09.127'},
#    'AverageSpeed': {'units': 'kph', 'speed': '175.613'}}},
#  {'number': '24',
#   'position': '20',
#   'positionText': 'R',
#   'points': '0',
#   'Driver': {'driverId': 'glock',
#    'code': 'GLO',
#    'url': 'http://en.wikipedia.org/wiki/Timo_Glock',
#    'givenName': 'Timo',
#    'familyName': 'Glock',
#    'dateOfBirth': '1982-03-18',
#    'nationality': 'German'},
#   'Constructor': {'constructorId': 'virgin',
#    'url': 'http://en.wikipedia.org/wiki/Virgin_Racing',
#    'name': 'Virgin',
#    'nationality': 'British'},
#   'grid': '19',
#   'laps': '16',
#   'status': 'Gearbox',
#   'FastestLap': {'rank': '21',
#    'lap': '11',
#    'Time': {'time': '2:07.062'},
#    'AverageSpeed': {'units': 'kph', 'speed': '178.467'}}},
#  {'number': '12',
#   'position': '21',
#   'positionText': 'R',
#   'points': '0',
#   'Driver': {'driverId': 'petrov',
#    'code': 'PET',
#    'url': 'http://en.wikipedia.org/wiki/Vitaly_Petrov',
#    'givenName': 'Vitaly',
#    'familyName': 'Petrov',
#    'dateOfBirth': '1984-09-08',
#    'nationality': 'Russian'},
#   'Constructor': {'constructorId': 'renault',
#    'url': 'http://en.wikipedia.org/wiki/Renault_in_Formula_One',
#    'name': 'Renault',
#    'nationality': 'French'},
#   'grid': '17',
#   'laps': '13',
#   'status': 'Suspension',
#   'FastestLap': {'rank': '19',
#    'lap': '7',
#    'Time': {'time': '2:04.307'},
#    'AverageSpeed': {'units': 'kph', 'speed': '182.422'}}},
#  {'number': '23',
#   'position': '22',
#   'positionText': 'R',
#   'points': '0',
#   'Driver': {'driverId': 'kobayashi',
#    'permanentNumber': '10',
#    'code': 'KOB',
#    'url': 'http://en.wikipedia.org/wiki/Kamui_Kobayashi',
#    'givenName': 'Kamui',
#    'familyName': 'Kobayashi',
#    'dateOfBirth': '1986-09-13',
#    'nationality': 'Japanese'},
#   'Constructor': {'constructorId': 'sauber',
#    'url': 'http://en.wikipedia.org/wiki/Sauber',
#    'name': 'Sauber',
#    'nationality': 'Swiss'},
#   'grid': '16',
#   'laps': '11',
#   'status': 'Hydraulics',
#   'FastestLap': {'rank': '20',
#    'lap': '4',
#    'Time': {'time': '2:05.044'},
#    'AverageSpeed': {'units': 'kph', 'speed': '181.347'}}},
#  {'number': '25',
#   'position': '23',
#   'positionText': 'R',
#   'points': '0',
#   'Driver': {'driverId': 'grassi',
#    'code': 'DIG',
#    'url': 'http://en.wikipedia.org/wiki/Lucas_di_Grassi',
#    'givenName': 'Lucas',
#    'familyName': 'di Grassi',
#    'dateOfBirth': '1984-08-11',
#    'nationality': 'Brazilian'},
#   'Constructor': {'constructorId': 'virgin',
#    'url': 'http://en.wikipedia.org/wiki/Virgin_Racing',
#    'name': 'Virgin',
#    'nationality': 'British'},
#   'grid': '22',
#   'laps': '2',
#   'status': 'Hydraulics',
#   'FastestLap': {'rank': '23',
#    'lap': '2',
#    'Time': {'time': '2:09.361'},
#    'AverageSpeed': {'units': 'kph', 'speed': '175.295'}}},
#  {'number': '20',
#   'position': '24',
#   'positionText': 'R',
#   'points': '0',
#   'Driver': {'driverId': 'chandhok',
#    'code': 'CHA',
#    'url': 'http://en.wikipedia.org/wiki/Karun_Chandhok',
#    'givenName': 'Karun',
#    'familyName': 'Chandhok',
#    'dateOfBirth': '1984-01-19',
#    'nationality': 'Indian'},
#   'Constructor': {'constructorId': 'hrt',
#    'url': 'http://en.wikipedia.org/wiki/Hispania_Racing',
#    'name': 'HRT',
#    'nationality': 'Spanish'},
#   'grid': '24',
#   'laps': '1',
#   'status': 'Accident'}]

# %%
res={'driver':[],'cons':[],'num':[],'pos':[],'postex':[],'poi':[],'grid':[],'laps':[],'tim':[],'millis':[],'fastl':[],'rank':[]}
for year in list(range(2010,2023)):
    url='http://ergast.com/api/f1/{}/results.json'
    response = requests.get(url.format(year))
    content=json.loads(response.content)
    for item in  content['MRData']['RaceTable']['Races'][0]['Results']:
        try:
            res['fastl'].append(item['FastestLap']['lap'])
        except:
            res['fastl'].append(np.nan)
        try:
            res['rank'].append(item['FastestLap']['rank'])
        except:
            res['rank'].append(np.nan)
        res['cons'].append(item['Constructor']['constructorId'])
        res['driver'].append(item['Driver']['driverId'])
        res['num'].append(item['number'])
        res['pos'].append(item['position'])
        res['postex'].append(item['positionText'])
        res['poi'].append(item['points'])
        res['grid'].append(item['grid'])
        res['laps'].append(item['laps'])
        try:
            res['tim'].append(item['Time']['time'])
        except:
            res['tim'].append(np.nan)
        try:
            res['millis'].append(item['Time']['millis'])
        except:
            res['millis'].append(np.nan)
    for item in  content['MRData']['RaceTable']['Races'][1]['Results']:
        try:
            res['fastl'].append(item['FastestLap']['lap'])
        except:
            res['fastl'].append(np.nan)
        try:
            res['rank'].append(item['FastestLap']['rank'])
        except:
            res['rank'].append(np.nan)
        res['cons'].append(item['Constructor']['constructorId'])
        res['driver'].append(item['Driver']['driverId'])
        res['num'].append(item['number'])
        res['pos'].append(item['position'])
        res['postex'].append(item['positionText'])
        res['poi'].append(item['points'])
        res['grid'].append(item['grid'])
        res['laps'].append(item['laps'])
        try:
            res['tim'].append(item['Time']['time'])
        except:
            res['tim'].append(np.nan)
        try:
            res['millis'].append(item['Time']['millis'])
        except:
            res['millis'].append(np.nan)
        
   
pd.DataFrame(res).to_csv('resultados.csv', index=False)

# %% [markdown]
# # Tabla SpringResults

# %%
url = 'http://ergast.com/api/f1/sprint.json'
response = requests.get(url)
content=json.loads(response.content)

# %%
content['MRData']['RaceTable']['Races'][0]['SprintResults']
# Out:
# [{'number': '33',
#   'position': '1',
#   'positionText': '1',
#   'points': '3',
#   'Driver': {'driverId': 'max_verstappen',
#    'permanentNumber': '33',
#    'code': 'VER',
#    'url': 'http://en.wikipedia.org/wiki/Max_Verstappen',
#    'givenName': 'Max',
#    'familyName': 'Verstappen',
#    'dateOfBirth': '1997-09-30',
#    'nationality': 'Dutch'},
#   'Constructor': {'constructorId': 'red_bull',
#    'url': 'http://en.wikipedia.org/wiki/Red_Bull_Racing',
#    'name': 'Red Bull',
#    'nationality': 'Austrian'},
#   'grid': '2',
#   'laps': '17',
#   'status': 'Finished',
#   'Time': {'millis': '1538426', 'time': '25:38.426'},
#   'FastestLap': {'lap': '14', 'Time': {'time': '1:30.013'}}},
#  {'number': '44',
#   'position': '2',
#   'positionText': '2',
#   'points': '2',
#   'Driver': {'driverId': 'hamilton',
#    'permanentNumber': '44',
#    'code': 'HAM',
#    'url': 'http://en.wikipedia.org/wiki/Lewis_Hamilton',
#    'givenName': 'Lewis',
#    'familyName': 'Hamilton',
#    'dateOfBirth': '1985-01-07',
#    'nationality': 'British'},
#   'Constructor': {'constructorId': 'mercedes',
#    'url': 'http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One',
#    'name': 'Mercedes',
#    'nationality': 'German'},
#   'grid': '1',
#   'laps': '17',
#   'status': 'Finished',
#   'Time': {'millis': '1539856', 'time': '+1.430'},
#   'FastestLap': {'lap': '17', 'Time': {'time': '1:29.937'}}},
#  {'number': '77',
#   'position': '3',
#   'positionText': '3',
#   'points': '1',
#   'Driver': {'driverId': 'bottas',
#    'permanentNumber': '77',
#    'code': 'BOT',
#    'url': 'http://en.wikipedia.org/wiki/Valtteri_Bottas',
#    'givenName': 'Valtteri',
#    'familyName': 'Bottas',
#    'dateOfBirth': '1989-08-28',
#    'nationality': 'Finnish'},
#   'Constructor': {'constructorId': 'mercedes',
#    'url': 'http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One',
#    'name': 'Mercedes',
#    'nationality': 'German'},
#   'grid': '3',
#   'laps': '17',
#   'status': 'Finished',
#   'Time': {'millis': '1545928', 'time': '+7.502'},
#   'FastestLap': {'lap': '17', 'Time': {'time': '1:29.958'}}},
#  {'number': '16',
#   'position': '4',
#   'positionText': '4',
#   'points': '0',
#   'Driver': {'driverId': 'leclerc',
#    'permanentNumber': '16',
#    'code': 'LEC',
#    'url': 'http://en.wikipedia.org/wiki/Charles_Leclerc',
#    'givenName': 'Charles',
#    'familyName': 'Leclerc',
#    'dateOfBirth': '1997-10-16',
#    'nationality': 'Monegasque'},
#   'Constructor': {'constructorId': 'ferrari',
#    'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#    'name': 'Ferrari',
#    'nationality': 'Italian'},
#   'grid': '4',
#   'laps': '17',
#   'status': 'Finished',
#   'Time': {'millis': '1549704', 'time': '+11.278'},
#   'FastestLap': {'lap': '16', 'Time': {'time': '1:30.163'}}},
#  {'number': '4',
#   'position': '5',
#   'positionText': '5',
#   'points': '0',
#   'Driver': {'driverId': 'norris',
#    'permanentNumber': '4',
#    'code': 'NOR',
#    'url': 'http://en.wikipedia.org/wiki/Lando_Norris',
#    'givenName': 'Lando',
#    'familyName': 'Norris',
#    'dateOfBirth': '1999-11-13',
#    'nationality': 'British'},
#   'Constructor': {'constructorId': 'mclaren',
#    'url': 'http://en.wikipedia.org/wiki/McLaren',
#    'name': 'McLaren',
#    'nationality': 'British'},
#   'grid': '6',
#   'laps': '17',
#   'status': 'Finished',
#   'Time': {'millis': '1562537', 'time': '+24.111'},
#   'FastestLap': {'lap': '16', 'Time': {'time': '1:30.566'}}},
#  {'number': '3',
#   'position': '6',
#   'positionText': '6',
#   'points': '0',
#   'Driver': {'driverId': 'ricciardo',
#    'permanentNumber': '3',
#    'code': 'RIC',
#    'url': 'http://en.wikipedia.org/wiki/Daniel_Ricciardo',
#    'givenName': 'Daniel',
#    'familyName': 'Ricciardo',
#    'dateOfBirth': '1989-07-01',
#    'nationality': 'Australian'},
#   'Constructor': {'constructorId': 'mclaren',
#    'url': 'http://en.wikipedia.org/wiki/McLaren',
#    'name': 'McLaren',
#    'nationality': 'British'},
#   'grid': '7',
#   'laps': '17',
#   'status': 'Finished',
#   'Time': {'millis': '1569385', 'time': '+30.959'},
#   'FastestLap': {'lap': '17', 'Time': {'time': '1:30.640'}}},
#  {'number': '14',
#   'position': '7',
#   'positionText': '7',
#   'points': '0',
#   'Driver': {'driverId': 'alonso',
#    'permanentNumber': '14',
#    'code': 'ALO',
#    'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#    'givenName': 'Fernando',
#    'familyName': 'Alonso',
#    'dateOfBirth': '1981-07-29',
#    'nationality': 'Spanish'},
#   'Constructor': {'constructorId': 'alpine',
#    'url': 'http://en.wikipedia.org/wiki/Alpine_F1_Team',
#    'name': 'Alpine F1 Team',
#    'nationality': 'French'},
#   'grid': '11',
#   'laps': '17',
#   'status': 'Finished',
#   'Time': {'millis': '1581953', 'time': '+43.527'},
#   'FastestLap': {'lap': '17', 'Time': {'time': '1:31.773'}}},
#  {'number': '5',
#   'position': '8',
#   'positionText': '8',
#   'points': '0',
#   'Driver': {'driverId': 'vettel',
#    'permanentNumber': '5',
#    'code': 'VET',
#    'url': 'http://en.wikipedia.org/wiki/Sebastian_Vettel',
#    'givenName': 'Sebastian',
#    'familyName': 'Vettel',
#    'dateOfBirth': '1987-07-03',
#    'nationality': 'German'},
#   'Constructor': {'constructorId': 'aston_martin',
#    'url': 'http://en.wikipedia.org/wiki/Aston_Martin_in_Formula_One',
#    'name': 'Aston Martin',
#    'nationality': 'British'},
#   'grid': '10',
#   'laps': '17',
#   'status': 'Finished',
#   'Time': {'millis': '1582865', 'time': '+44.439'},
#   'FastestLap': {'lap': '17', 'Time': {'time': '1:31.687'}}},
#  {'number': '63',
#   'position': '9',
#   'positionText': '9',
#   'points': '0',
#   'Driver': {'driverId': 'russell',
#    'permanentNumber': '63',
#    'code': 'RUS',
#    'url': 'http://en.wikipedia.org/wiki/George_Russell_%28racing_driver%29',
#    'givenName': 'George',
#    'familyName': 'Russell',
#    'dateOfBirth': '1998-02-15',
#    'nationality': 'British'},
#   'Constructor': {'constructorId': 'williams',
#    'url': 'http://en.wikipedia.org/wiki/Williams_Grand_Prix_Engineering',
#    'name': 'Williams',
#    'nationality': 'British'},
#   'grid': '8',
#   'laps': '17',
#   'status': 'Finished',
#   'Time': {'millis': '1585078', 'time': '+46.652'},
#   'FastestLap': {'lap': '17', 'Time': {'time': '1:32.208'}}},
#  {'number': '31',
#   'position': '10',
#   'positionText': '10',
#   'points': '0',
#   'Driver': {'driverId': 'ocon',
#    'permanentNumber': '31',
#    'code': 'OCO',
#    'url': 'http://en.wikipedia.org/wiki/Esteban_Ocon',
#    'givenName': 'Esteban',
#    'familyName': 'Ocon',
#    'dateOfBirth': '1996-09-17',
#    'nationality': 'French'},
#   'Constructor': {'constructorId': 'alpine',
#    'url': 'http://en.wikipedia.org/wiki/Alpine_F1_Team',
#    'name': 'Alpine F1 Team',
#    'nationality': 'French'},
#   'grid': '13',
#   'laps': '17',
#   'status': 'Finished',
#   'Time': {'millis': '1585821', 'time': '+47.395'},
#   'FastestLap': {'lap': '16', 'Time': {'time': '1:32.183'}}},
#  {'number': '55',
#   'position': '11',
#   'positionText': '11',
#   'points': '0',
#   'Driver': {'driverId': 'sainz',
#    'permanentNumber': '55',
#    'code': 'SAI',
#    'url': 'http://en.wikipedia.org/wiki/Carlos_Sainz_Jr.',
#    'givenName': 'Carlos',
#    'familyName': 'Sainz',
#    'dateOfBirth': '1994-09-01',
#    'nationality': 'Spanish'},
#   'Constructor': {'constructorId': 'ferrari',
#    'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#    'name': 'Ferrari',
#    'nationality': 'Italian'},
#   'grid': '9',
#   'laps': '17',
#   'status': 'Finished',
#   'Time': {'millis': '1586224', 'time': '+47.798'},
#   'FastestLap': {'lap': '10', 'Time': {'time': '1:31.991'}}},
#  {'number': '10',
#   'position': '12',
#   'positionText': '12',
#   'points': '0',
#   'Driver': {'driverId': 'gasly',
#    'permanentNumber': '10',
#    'code': 'GAS',
#    'url': 'http://en.wikipedia.org/wiki/Pierre_Gasly',
#    'givenName': 'Pierre',
#    'familyName': 'Gasly',
#    'dateOfBirth': '1996-02-07',
#    'nationality': 'French'},
#   'Constructor': {'constructorId': 'alphatauri',
#    'url': 'http://en.wikipedia.org/wiki/Scuderia_AlphaTauri',
#    'name': 'AlphaTauri',
#    'nationality': 'Italian'},
#   'grid': '12',
#   'laps': '17',
#   'status': 'Finished',
#   'Time': {'millis': '1587189', 'time': '+48.763'},
#   'FastestLap': {'lap': '17', 'Time': {'time': '1:32.072'}}},
#  {'number': '7',
#   'position': '13',
#   'positionText': '13',
#   'points': '0',
#   'Driver': {'driverId': 'raikkonen',
#    'permanentNumber': '7',
#    'code': 'RAI',
#    'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#    'givenName': 'Kimi',
#    'familyName': 'Räikkönen',
#    'dateOfBirth': '1979-10-17',
#    'nationality': 'Finnish'},
#   'Constructor': {'constructorId': 'alfa',
#    'url': 'http://en.wikipedia.org/wiki/Alfa_Romeo_in_Formula_One',
#    'name': 'Alfa Romeo',
#    'nationality': 'Swiss'},
#   'grid': '17',
#   'laps': '17',
#   'status': 'Finished',
#   'Time': {'millis': '1589103', 'time': '+50.677'},
#   'FastestLap': {'lap': '12', 'Time': {'time': '1:32.139'}}},
#  {'number': '18',
#   'position': '14',
#   'positionText': '14',
#   'points': '0',
#   'Driver': {'driverId': 'stroll',
#    'permanentNumber': '18',
#    'code': 'STR',
#    'url': 'http://en.wikipedia.org/wiki/Lance_Stroll',
#    'givenName': 'Lance',
#    'familyName': 'Stroll',
#    'dateOfBirth': '1998-10-29',
#    'nationality': 'Canadian'},
#   'Constructor': {'constructorId': 'aston_martin',
#    'url': 'http://en.wikipedia.org/wiki/Aston_Martin_in_Formula_One',
#    'name': 'Aston Martin',
#    'nationality': 'British'},
#   'grid': '15',
#   'laps': '17',
#   'status': 'Finished',
#   'Time': {'millis': '1590605', 'time': '+52.179'},
#   'FastestLap': {'lap': '12', 'Time': {'time': '1:32.210'}}},
#  {'number': '99',
#   'position': '15',
#   'positionText': '15',
#   'points': '0',
#   'Driver': {'driverId': 'giovinazzi',
#    'permanentNumber': '99',
#    'code': 'GIO',
#    'url': 'http://en.wikipedia.org/wiki/Antonio_Giovinazzi',
#    'givenName': 'Antonio',
#    'familyName': 'Giovinazzi',
#    'dateOfBirth': '1993-12-14',
#    'nationality': 'Italian'},
#   'Constructor': {'constructorId': 'alfa',
#    'url': 'http://en.wikipedia.org/wiki/Alfa_Romeo_in_Formula_One',
#    'name': 'Alfa Romeo',
#    'nationality': 'Swiss'},
#   'grid': '14',
#   'laps': '17',
#   'status': 'Finished',
#   'Time': {'millis': '1591651', 'time': '+53.225'},
#   'FastestLap': {'lap': '14', 'Time': {'time': '1:32.457'}}},
#  {'number': '22',
#   'position': '16',
#   'positionText': '16',
#   'points': '0',
#   'Driver': {'driverId': 'tsunoda',
#    'permanentNumber': '22',
#    'code': 'TSU',
#    'url': 'http://en.wikipedia.org/wiki/Yuki_Tsunoda',
#    'givenName': 'Yuki',
#    'familyName': 'Tsunoda',
#    'dateOfBirth': '2000-05-11',
#    'nationality': 'Japanese'},
#   'Constructor': {'constructorId': 'alphatauri',
#    'url': 'http://en.wikipedia.org/wiki/Scuderia_AlphaTauri',
#    'name': 'AlphaTauri',
#    'nationality': 'Italian'},
#   'grid': '16',
#   'laps': '17',
#   'status': 'Finished',
#   'Time': {'millis': '1591993', 'time': '+53.567'},
#   'FastestLap': {'lap': '14', 'Time': {'time': '1:32.270'}}},
#  {'number': '6',
#   'position': '17',
#   'positionText': '17',
#   'points': '0',
#   'Driver': {'driverId': 'latifi',
#    'permanentNumber': '6',
#    'code': 'LAT',
#    'url': 'http://en.wikipedia.org/wiki/Nicholas_Latifi',
#    'givenName': 'Nicholas',
#    'familyName': 'Latifi',
#    'dateOfBirth': '1995-06-29',
#    'nationality': 'Canadian'},
#   'Constructor': {'constructorId': 'williams',
#    'url': 'http://en.wikipedia.org/wiki/Williams_Grand_Prix_Engineering',
#    'name': 'Williams',
#    'nationality': 'British'},
#   'grid': '18',
#   'laps': '17',
#   'status': 'Finished',
#   'Time': {'millis': '1593588', 'time': '+55.162'},
#   'FastestLap': {'lap': '17', 'Time': {'time': '1:32.143'}}},
#  {'number': '47',
#   'position': '18',
#   'positionText': '18',
#   'points': '0',
#   'Driver': {'driverId': 'mick_schumacher',
#    'permanentNumber': '47',
#    'code': 'MSC',
#    'url': 'http://en.wikipedia.org/wiki/Mick_Schumacher',
#    'givenName': 'Mick',
#    'familyName': 'Schumacher',
#    'dateOfBirth': '1999-03-22',
#    'nationality': 'German'},
#   'Constructor': {'constructorId': 'haas',
#    'url': 'http://en.wikipedia.org/wiki/Haas_F1_Team',
#    'name': 'Haas F1 Team',
#    'nationality': 'American'},
#   'grid': '19',
#   'laps': '17',
#   'status': 'Finished',
#   'Time': {'millis': '1606639', 'time': '+1:08.213'},
#   'FastestLap': {'lap': '15', 'Time': {'time': '1:32.567'}}},
#  {'number': '9',
#   'position': '19',
#   'positionText': '19',
#   'points': '0',
#   'Driver': {'driverId': 'mazepin',
#    'permanentNumber': '9',
#    'code': 'MAZ',
#    'url': 'http://en.wikipedia.org/wiki/Nikita_Mazepin',
#    'givenName': 'Nikita',
#    'familyName': 'Mazepin',
#    'dateOfBirth': '1999-03-02',
#    'nationality': 'Russian'},
#   'Constructor': {'constructorId': 'haas',
#    'url': 'http://en.wikipedia.org/wiki/Haas_F1_Team',
#    'name': 'Haas F1 Team',
#    'nationality': 'American'},
#   'grid': '20',
#   'laps': '17',
#   'status': 'Finished',
#   'Time': {'millis': '1616074', 'time': '+1:17.648'},
#   'FastestLap': {'lap': '3', 'Time': {'time': '1:33.462'}}},
#  {'number': '11',
#   'position': '20',
#   'positionText': 'R',
#   'points': '0',
#   'Driver': {'driverId': 'perez',
#    'permanentNumber': '11',
#    'code': 'PER',
#    'url': 'http://en.wikipedia.org/wiki/Sergio_P%C3%A9rez',
#    'givenName': 'Sergio',
#    'familyName': 'Pérez',
#    'dateOfBirth': '1990-01-26',
#    'nationality': 'Mexican'},
#   'Constructor': {'constructorId': 'red_bull',
#    'url': 'http://en.wikipedia.org/wiki/Red_Bull_Racing',
#    'name': 'Red Bull',
#    'nationality': 'Austrian'},
#   'grid': '5',
#   'laps': '16',
#   'status': 'Vibrations',
#   'FastestLap': {'lap': '6', 'Time': {'time': '1:31.465'}}}]

# %%
spr={'driveID':[],'constructorid':[],'num':[],'grid':[],'pos':[],'postex':[],'points':[],'laps':[],'time':[],'millis':[],
     'status':[],'fastl':[],'fastt':[]}
for year in list(range(2021,2023)):
    url='http://ergast.com/api/f1/{}/sprint.json'
    response = requests.get(url.format(year))
    content=json.loads(response.content)
    for item in content['MRData']['RaceTable']['Races'][0]['SprintResults']:
        spr['driveID'].append(item['Driver']['driverId'])
        spr['constructorid'].append(item['Constructor']['constructorId'])
        spr['num'].append(item['number'])
        spr['grid'].append(item['grid'])
        spr['pos'].append(item['position'])
        spr['postex'].append(item['positionText'])
        spr['points'].append(item['points'])
        spr['laps'].append(item['laps'])
        try:
            spr['time'].append(item['Time']['time'])
        except:
            spr['time'].append(np.nan)
        try:
            spr['millis'].append(item['Time']['millis'])
        except:
            spr['millis'].append(np.nan)
        try:
            spr['status'].append(item['status'])
        except:
            spr['status'].append(np.nan)
        try:
            spr['fastl'].append(item['FastestLap']['lap'])
        except:
            spr['fastl'].append(np.nan)
        try:
            spr['fastt'].append(item['FastestLap']['Time']['time'])
        except:
            spr['fastt'].append(np.nan)
    for item in content['MRData']['RaceTable']['Races'][1]['SprintResults']:
        spr['driveID'].append(item['Driver']['driverId'])
        spr['constructorid'].append(item['Constructor']['constructorId'])
        spr['num'].append(item['number'])
        spr['grid'].append(item['grid'])
        spr['pos'].append(item['position'])
        spr['postex'].append(item['positionText'])
        spr['points'].append(item['points'])
        spr['laps'].append(item['laps'])
        try:
            spr['time'].append(item['Time']['time'])
        except:
            spr['time'].append(np.nan)
        try:
            spr['millis'].append(item['Time']['millis'])
        except:
            spr['millis'].append(np.nan)
        try:
            spr['status'].append(item['status'])
        except:
            spr['status'].append(np.nan)
        try:
            spr['fastl'].append(item['FastestLap']['lap'])
        except:
            spr['fastl'].append(np.nan)
        try:
            spr['fastt'].append(item['FastestLap']['Time']['time'])
        except:
            spr['fastt'].append(np.nan)

pd.DataFrame(spr).to_csv('sprintresults.csv', index=False)

# %% [markdown]
# # Tabla pitStops

# %%
url = 'http://ergast.com/api/f1/2011/5/pitstops.json'
response = requests.get(url)
content=json.loads(response.content)

# %%
content['MRData']['RaceTable']['Races']
# Out:
# [{'season': '2011',
#   'round': '5',
#   'url': 'http://en.wikipedia.org/wiki/2011_Spanish_Grand_Prix',
#   'raceName': 'Spanish Grand Prix',
#   'Circuit': {'circuitId': 'catalunya',
#    'url': 'http://en.wikipedia.org/wiki/Circuit_de_Barcelona-Catalunya',
#    'circuitName': 'Circuit de Barcelona-Catalunya',
#    'Location': {'lat': '41.57',
#     'long': '2.26111',
#     'locality': 'Montmeló',
#     'country': 'Spain'}},
#   'date': '2011-05-22',
#   'time': '12:00:00Z',
#   'PitStops': [{'driverId': 'kobayashi',
#     'lap': '1',
#     'stop': '1',
#     'time': '14:05:11',
#     'duration': '24.871'},
#    {'driverId': 'perez',
#     'lap': '7',
#     'stop': '1',
#     'time': '14:14:14',
#     'duration': '23.592'},
#    {'driverId': 'maldonado',
#     'lap': '8',
#     'stop': '1',
#     'time': '14:15:48',
#     'duration': '22.689'},
#    {'driverId': 'vettel',
#     'lap': '9',
#     'stop': '1',
#     'time': '14:16:54',
#     'duration': '20.253'},
#    {'driverId': 'buemi',
#     'lap': '9',
#     'stop': '1',
#     'time': '14:17:17',
#     'duration': '20.818'},
#    {'driverId': 'alonso',
#     'lap': '10',
#     'stop': '1',
#     'time': '14:18:23',
#     'duration': '20.567'},
#    {'driverId': 'webber',
#     'lap': '10',
#     'stop': '1',
#     'time': '14:18:27',
#     'duration': '20.881'},
#    {'driverId': 'michael_schumacher',
#     'lap': '10',
#     'stop': '1',
#     'time': '14:18:43',
#     'duration': '20.084'},
#    {'driverId': 'hamilton',
#     'lap': '11',
#     'stop': '1',
#     'time': '14:19:57',
#     'duration': '19.761'},
#    {'driverId': 'petrov',
#     'lap': '11',
#     'stop': '1',
#     'time': '14:20:14',
#     'duration': '21.856'},
#    {'driverId': 'rosberg',
#     'lap': '11',
#     'stop': '1',
#     'time': '14:20:17',
#     'duration': '20.647'},
#    {'driverId': 'massa',
#     'lap': '11',
#     'stop': '1',
#     'time': '14:20:19',
#     'duration': '20.800'},
#    {'driverId': 'alguersuari',
#     'lap': '11',
#     'stop': '1',
#     'time': '14:20:28',
#     'duration': '20.741'},
#    {'driverId': 'barrichello',
#     'lap': '11',
#     'stop': '1',
#     'time': '14:20:48',
#     'duration': '29.936'},
#    {'driverId': 'sutil',
#     'lap': '13',
#     'stop': '1',
#     'time': '14:23:57',
#     'duration': '20.773'},
#    {'driverId': 'button',
#     'lap': '14',
#     'stop': '1',
#     'time': '14:24:51',
#     'duration': '20.015'},
#    {'driverId': 'karthikeyan',
#     'lap': '14',
#     'stop': '1',
#     'time': '14:25:56',
#     'duration': '24.843'},
#    {'driverId': 'resta',
#     'lap': '15',
#     'stop': '1',
#     'time': '14:26:40',
#     'duration': '20.070'},
#    {'driverId': 'trulli',
#     'lap': '15',
#     'stop': '1',
#     'time': '14:26:50',
#     'duration': '22.364'},
#    {'driverId': 'kovalainen',
#     'lap': '16',
#     'stop': '1',
#     'time': '14:28:30',
#     'duration': '21.019'},
#    {'driverId': 'liuzzi',
#     'lap': '16',
#     'stop': '1',
#     'time': '14:28:55',
#     'duration': '23.157'},
#    {'driverId': 'glock',
#     'lap': '16',
#     'stop': '1',
#     'time': '14:29:00',
#     'duration': '22.744'},
#    {'driverId': 'ambrosio',
#     'lap': '17',
#     'stop': '1',
#     'time': '14:30:41',
#     'duration': '23.176'},
#    {'driverId': 'vettel',
#     'lap': '18',
#     'stop': '2',
#     'time': '14:30:44',
#     'duration': '19.887'},
#    {'driverId': 'alonso',
#     'lap': '19',
#     'stop': '2',
#     'time': '14:32:13',
#     'duration': '20.238'},
#    {'driverId': 'webber',
#     'lap': '19',
#     'stop': '2',
#     'time': '14:32:16',
#     'duration': '20.079'},
#    {'driverId': 'maldonado',
#     'lap': '20',
#     'stop': '2',
#     'time': '14:34:36',
#     'duration': '24.821'},
#    {'driverId': 'massa',
#     'lap': '21',
#     'stop': '2',
#     'time': '14:35:51',
#     'duration': '21.635'},
#    {'driverId': 'heidfeld',
#     'lap': '21',
#     'stop': '1',
#     'time': '14:36:21',
#     'duration': '21.322'},
#    {'driverId': 'hamilton',
#     'lap': '23',
#     'stop': '2',
#     'time': '14:38:08',
#     'duration': '20.235'}]}]

# %%
pits={'driverid':[],'lap':[],'stop':[],'time':[],'duration':[]}
for year in list(range(2011,2023)):
    url='http://ergast.com/api/f1/{}/5/pitstops.json'
    response = requests.get(url.format(year))
    content=json.loads(response.content)
    for item in content['MRData']['RaceTable']['Races'][0]['PitStops']:
        pits['driverid'].append(item['driverId'])
        pits['lap'].append(item['lap'])
        pits['stop'].append(item['stop'])
        pits['time'].append(item['time'])
        pits['duration'].append(item['duration'])
pd.DataFrame(pits).to_csv('pitstops.csv',index=False)

# %% [markdown]
# # Tabla de Races (Faltante de la tarea pasada)

# %%
races={'season':[],
      'round':[],
      'raceName':[],
      'circuitId':[],
      'lat':[],
      'long':[],
      'country':[],
      'date':[],
      'url':[]}
for year in list(range(2010,2023)):
    url='https://ergast.com/api/f1/{}.json'
    response =requests.get(url.format(year))
    content= json.loads(response.content)
    for item in content ['MRData']['RaceTable']['Races']:
        races['season'].append(int(item['season']))
        races['round'].append(int(item['round']))
        races['raceName'].append(item['raceName'])
        races['circuitId'].append(item['Circuit']['circuitId'])
        races['lat'].append(item['Circuit']['Location']['lat'])
        races['long'].append(item['Circuit']['Location']['long'])
        races['country'].append(item['Circuit']['Location']['country'])
        races['date'].append(item['date'])
        races['url'].append(item['url'])
pd.DataFrame(races).to_csv('races.csv',index=False)

# %% [markdown]
# # Tabla seasons (Faltante de la tarea pasada)

# %%
dic ={'temporada':[],'url':[]}
for year in list(range(2010,2023)):
    url='https://ergast.com/api/f1/{}/seasons.json'
    response =requests.get(url.format(year))
    content= json.loads(response.content)
    for item in content['MRData']['SeasonTable']['Seasons']:
        dic['temporada'].append(int(item['season']))
        dic['url'].append(item['url'])
pd.DataFrame(dic).to_csv('season.csv', index= False)
